# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
from einops import rearrange
from PIL import Image
from tqdm import tqdm
import json
import time
from pathlib import Path
from sklearn import linear_model
import mediapy as media

# %%
# !ls -lt session_test
# Out:
# total 307496
# -rw-r--r-- 1 marwi 197609    5362 Jan 21 11:27 curframe_2a898c50.jpeg
# -rw-r--r-- 1 marwi 197609    5066 Jan 21 11:27 curframe_2add1ada.jpeg
# -rw-r--r-- 1 marwi 197609    5510 Jan 21 11:27 curframe_d67600e4.jpeg
# -rw-r--r-- 1 marwi 197609    6583 Jan 21 11:27 curframe_f29deae1.jpeg
# -rw-r--r-- 1 marwi 197609    6583 Jan 21 11:27 curframe_055b0ca5.jpeg
# -rw-r--r-- 1 marwi 197609    6326 Jan 21 11:27 curframe_ac727ebd.jpeg
# -rw-r--r-- 1 marwi 197609    5066 Jan 21 11:27 curframe_4cd8b0ed.jpeg
# -rw-r--r-- 1 marwi 197609    5066 Jan 21 11:27 curframe_94c4b94c.jpeg
# -rw-r--r-- 1 marwi 197609 4783332 Jan 21 11:27 agent_stats_2add1ada.csv.gz
# -rw-r--r-- 1 marwi 197609 4788419 Jan 21 11:27 agent_stats_d67600e4.csv.gz
# -rw-r--r-- 1 marwi 197609 4775483 Jan 21 11:27 agent_stats_4cd8b0ed.csv.gz
# -rw-r--r-- 1 marwi 197609 4777614 Jan 21 11:27 agent_stats_055b0ca5.csv.gz
# -rw-r--r-- 1 marwi 197609 4767226 Jan 21 11:27 agent_stats_2a898c50.csv.gz
# -rw-r--r-- 1 marwi 197609 4781516 Jan 21 11:27 agent_stats_ac727ebd.csv.gz
# -rw-r--r-- 1 marwi 197609 4780222 Jan 21 11:27 agent_stats_f29deae1.csv.gz
# -rw-r--r-- 1 marwi 197609 4780820 Jan 21 11:27 agent_stats_94c4b94c.csv.gz
# -rw-r--r-- 1 marwi 197609    4740 Jan 21 11:27 all_runs_4cd8b0ed.json
# -rw-r--r-- 1 marwi 197609    4636 Jan 21 11:27 all_runs_94c4b94c.json
# -rw-r--r-- 1 marwi 197609    4659 Jan 21 11:27 all_runs_f29deae1.json
# -rw-r--r-- 1 marwi 197609    4610 Jan 21 11:27 all_runs_055b0ca5.json
# -rw-r--r-- 1 marwi 197609    4660 Jan 21 11:27 all_runs_2add1ada.json
# -rw-r--r-- 1 marwi 197609    4671 Jan 21 11:27 all_runs_ac727ebd.json
# -rw-r--r-- 1 marwi 197609    4621 Jan 21 11:27 all_runs_d67600e4.json
# drwxr-xr-x 1 marwi 197609       0 Jan 21 11:27 final_states
# -rw-r--r-- 1 marwi 197609    4658 Jan 21 11:27 all_runs_2a898c50.json
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:26 poke_6160384_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:24 poke_6029312_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:22 poke_5898240_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:20 poke_5767168_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:17 poke_5636096_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:15 poke_5505024_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 11:13 poke_5373952_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:11 poke_5242880_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:09 poke_5111808_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:06 poke_4980736_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:04 poke_4849664_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:02 poke_4718592_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 11:00 poke_4587520_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:58 poke_4456448_steps.zip
# drwxr-xr-x 1 marwi 197609       0 Jan 21 10:57 screenshots
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:56 poke_4325376_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:54 poke_4194304_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 10:52 poke_4063232_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:50 poke_3932160_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:49 poke_3801088_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:47 poke_3670016_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:45 poke_3538944_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:43 poke_3407872_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:41 poke_3276800_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:40 poke_3145728_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:38 poke_3014656_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:36 poke_2883584_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 10:34 poke_2752512_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:32 poke_2621440_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:31 poke_2490368_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:29 poke_2359296_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:27 poke_2228224_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:25 poke_2097152_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:24 poke_1966080_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:22 poke_1835008_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:20 poke_1703936_steps.zip
# -rw-r--r-- 1 marwi 197609 5952460 Jan 21 10:18 poke_1572864_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 10:17 poke_1441792_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 10:15 poke_1310720_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 10:13 poke_1179648_steps.zip
# -rw-r--r-- 1 marwi 197609 5952459 Jan 21 10:11 poke_1048576_steps.zip
# -rw-r--r-- 1 marwi 197609 5952458 Jan 21 10:09 poke_917504_steps.zip
# -rw-r--r-- 1 marwi 197609 5952458 Jan 21 10:07 poke_786432_steps.zip
# -rw-r--r-- 1 marwi 197609 5952458 Jan 21 10:06 poke_655360_steps.zip
# -rw-r--r-- 1 marwi 197609 5952458 Jan 21 10:04 poke_524288_steps.zip
# -rw-r--r-- 1 marwi 197609 5952458 Jan 21 10:02 poke_393216_steps.zip
# -rw-r--r-- 1 marwi 197609 5952458 Jan 21 10:00 poke_262144_steps.zip
# -rw-r--r-- 1 marwi 197609 2157822 Jan 21 09:58 poke_131072_steps.zip

# %%
def load_run_data(run_path):
    run_lists = []
    for p in Path(run_path).glob('all_runs_*.json'):
        with open(p, 'r') as f:
            run_lists.append(json.load(f))
    all_runs = [val for tup in zip(*run_lists) for val in tup]
    print(f'runs loaded: {len(all_runs)}')
    return all_runs

# %%
def plot_runs(
    all_runs, use_keys=None, 
    plot_fit=False, plot_line=False, 
    start=0, group_runs=1,
    agg_func=np.mean):
    
    all_runs = all_runs[start:]
    x = np.arange(len(all_runs)//group_runs)
    
    def add_plot(y, name, alpha, size, plot_line, plot_fit):
        plt.scatter(x, y, alpha=alpha, s=size, label=name)
        if plot_line:
            plt.plot(x, y, alpha=alpha, label=name)
        if plot_fit:
            regr = linear_model.LinearRegression()
            # Optimize linear model
            regr.fit(x.reshape(-1, 1), y.reshape(-1, 1))

            # Make predictions using the testing set
            lin_y = regr.predict(x.reshape(-1, 1))
            plt.plot(x, lin_y, linewidth=3)
    
    # convert list of dictionaries to dictionary of lists
    metrics = {m: [run[m] for run in all_runs] for m in all_runs[0].keys()}
    metrics['total'] = [sum([v for _,v in run.items()]) for run in all_runs]
    if group_runs:
        for m, dat in metrics.items():
            metrics[m] = agg_func(np.array(dat).reshape(-1, group_runs), 1)
    available_keys = metrics.keys()
    print(f'available metrics: {list(available_keys)}')
    if use_keys is None:
        use_keys = available_keys
    
    ## TODO subplot for each metric ## 
    NUM_COLORS = len(use_keys)
    cm = plt.get_cmap('Dark2')
    cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
    scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
    fig = plt.figure(figsize = (12, 8))

    ax = fig.add_subplot(111)
    ax.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

    for i, m in enumerate(use_keys):
        add_plot(
            np.array(metrics[m]), m, 1.0, 3.0, plot_line, plot_fit
        )

    plt.title('Reward over runs PPO')
    plt.legend(bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
    plt.show()

# %%
def get_latest_grid(pth):
    imgs = np.array([np.array(Image.open(p)) for p in Path(pth).glob('curframe*.jpeg')])
    grid = rearrange(imgs, '(h2 w2) h w c -> (h2 h) (w2 w) c', w2=4)
    return grid

# %%
'''
get_im_func = lambda: get_latest_grid('baselines/session_d34118d3')

with media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:
    for i in range(500):
        #wr.add_image(get_im_func())
        #time.sleep(1)
'''
# Out:
# "\nget_im_func = lambda: get_latest_grid('baselines/session_d34118d3')\n\nwith media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:\n    for i in range(500):\n        #wr.add_image(get_im_func())\n        #time.sleep(1)\n"

# %%
plt.figure(figsize=(32, 32))
plt.imshow(get_latest_grid('session_test'))

# %%
"(29556736 - 25952256) / (1024*16*44)"

# %%
plot_runs(
    load_run_data('session_test'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=8*0,
    group_runs=8,
    agg_func=np.mean
)
# hier immer num_cpu aus dem trainingsskript einsetzen für die zahl, z.B. 8, 44, ...
# Out:
# runs loaded: 376
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data('session_test'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=8,
    agg_func=np.mean
)
# Out:
# runs loaded: 376
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data('session_test'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 376
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data('session_test'),
    use_keys=['explore'],
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 376
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %%
plot_runs(
    load_run_data('session_test'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 376
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'total']

# %% [markdown]
# ### generate moving histograms

# %%
len(load_run_data('session_test'))
# Out:
# runs loaded: 376
# 376

# %%
def chunks(data, n):
    n = max(1, n)
    return [data[i:i+n] for i in range(0, len(data), n)]

# %%
full_dat = load_run_data('session_test')
for run in full_dat:
    run["total"] = sum(value for value in run.values())
full_dat_chunks = chunks(full_dat, 44)
# Out:
# runs loaded: 376

# %%
full_dat[0]
# Out:
# {'event': 0,
#  'level': 0,
#  'heal': 0,
#  'op_lvl': 0.0,
#  'dead': -0.0,
#  'badge': 0,
#  'explore': 2.415,
#  'total': 2.415}

# %%
def histo_plot(axis, stat, dat_chunks, version, compare_count):
    
    test_dat = np.array([run[stat] for run in dat_chunks[version]])
    # the histogram of the data
    n, bins, patches = axis.hist(test_dat, 10, density=False, facecolor="orange", alpha=0.95)
    
    for i in range(compare_count):
        comp_version = max(version - 1 - i, 0)
        compare_dat = np.array([run[stat] for run in dat_chunks[comp_version]])
        n, bins, patches = axis.hist(compare_dat, 10, density=False, facecolor="grey", alpha=0.2*0.25**i)

    axis.set(xlabel=f"{stat}")
    #axis.ylabel()
    # only use this title over all plots
    #axis.title()
    #plt.xlim(40, 160)
    #plt.ylim(0, 0.03)
    #axis.grid(True)
    #plt.show()

# %%
def plot_all(dat_chunks, version, compare_count):
    fig, axs = plt.subplots(2, 4, figsize=(16, 9), dpi=120)
    #plt.subplots_adjust(bottom=0.0, right=0.8, top=0.9)
    fig.suptitle(f"Version {version} Rewards")
    for stat, ax in zip(dat_chunks[0][0].keys(), axs.flatten()):
        histo_plot(ax, stat, dat_chunks, version, compare_count)
    return fig

# %%
plot_all(chunks(full_dat, 8), 10, 5)

# %%
#histo_plot("level", )

# %%
with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
    for i in tqdm(range(610)):
        #with plt.style.context('Solarize_Light2'):
        fig = plot_all(full_dat_chunks, i, 5)

        fig.canvas.draw()
        #plt.show()
        data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
        data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
        wr.add_image(data)
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
#       2     for i in tqdm(range(610)):
#       3         #with plt.style.context('Solarize_Light2'):
#       4         fig = plot_all(full_dat_chunks, i, 5)
#
# File c:\Users\marwi\anaconda3\envs\poke\lib\site-packages\mediapy\__init__.py:1328, in VideoWriter.__enter__(self)
#    1327 def __enter__(self) -> 'VideoWriter':
# -> 1328   ffmpeg_path = _get_ffmpeg_path()
#    1329   input_pix_fmt = self._get_pix_fmt(self.dtype, self.input_format)
#    1330   try:
#
# File c:\Users\marwi\anaconda3\envs\poke\lib\site-packages\mediapy\__init__.py:968, in _get_ffmpeg_path()
#     966 path = _search_for_ffmpeg_path()
#     967 if not path:
# --> 968   raise RuntimeError(
#     969       f"Program '{_config.ffmpeg_name_or_path}' is not found;"
#     970       " perhaps install ffmpeg using 'apt-get install ffmpeg'.")
#     971 return path
#
# RuntimeError: Program 'ffmpeg' is not found; perhaps install ffmpeg using 'apt-get install ffmpeg'.
